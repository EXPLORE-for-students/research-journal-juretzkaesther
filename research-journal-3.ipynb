# %% [markdown]
#  Research Notebook
#  Esther Juretzka
#  Date: 9/3/2026

# %% [markdown]
# # 1: Experience
# ## Describe at least one research activity you worked on this week.
#
# - number density plot of lmc particles within certain boundaries for snapshot 105
# - continued writing code with the goal to be able to trace LMC particles and also their number densities across multiple snapshots
# ## Motivation:
#
# As we want to see how the LMC is affecting the MW, tracing LMC particles across multiple snapshots is a good way to follow the dynamical evolution of the system
# Plotting the number density vs radius (r=0 is lmc center) lets us take a closer look at how the particles are distributed in radial bins

# %% [markdown]
# # 2: What? (What happened?)
# ## Describe what happened during your activities for the week.
#
# First, we took a step back and ran lots of sanity checks to be sure we are plotting the correct particles at the end.
# We added another filter when first selecting particles and printed them out.
# The first filter selects all dark matter particles within a radius of 800 kpc from the MW galaxy center.
# ![This code creates a filter that only includes DM particles within mw_r_cut.](images/mw_condition.png)
#  Then, we also want the ids belonging to these particles to be able to trace the particles later on.
# Next, a LMC filter is applied to the previously selected DM particles.
#  ![With this code all particles that are assigned to the LMC and within lmc_r_cut are stored in mw_lmc_particles. The same filter has to be applied to the IDs](images/lmc_mask.png)
# We also checked how the number of particles is changing with each filter as a sanity check. Furthermore, the particle list and ID list need to be the same length.(images/output.png)
# Additionaly, the tracing code has been worked on and changed. Now, there is a dictionary for the traced particles positions as well as their IDs, subflags and distance to respective LMC center.
# First, all particles with the same IDs as in snapshot 105 are filtered. Then, their distances to their LMC center is calculated, the radius cut is applied and they have to be assigned to the LMC.
# ![Tracing code](images/tracing_code.png)

# %% [markdown]
# # 3: So what? (What does it mean?)
# ## Describe your results
#
# Snapshot 105 is the reference snapshot and for that one a number density vs radius graph is plotted. The y-axis is in log-scale. (images/number_density_log_105.png)
#  *Figure displays a higher number density closer to the LMC center and decreases with increasing radius.
# ![Tracked LMC particles along a few snapshots ](images/tracked_lmc_new.png)
# That figure shows traced particles and it seems like the number of particles assigned to the LMC via subflag decreases a lot towards the present day as it is falling in to the MW.

# %% [markdown]
# # 4. Now what? (What's next?)
# ## Plan for the next week
#
# The next step is to find the number densities of LMC particles across multiple snapshots
# Furthermore it would be interesting to see the fraction of particles that is stripped away in comparison to the reference snapshot 105.
# One could display that in a fraction of density vs radius plot.

# %% [markdown]
# # 5. Bibliography
#
# -
